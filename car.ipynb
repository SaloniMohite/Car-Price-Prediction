# %%
import pandas as pd

# %%
# reading file 
df=pd.read_csv(r'C:\Users\HP\Documents\dataset\cardata.csv',encoding='latin-1')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Selling_type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
       'Fuel_Type', 'Selling_type', 'Transmission', 'Owner']]

# %%
# set new column as current year 
final_dataset['Current_Year']=2023

# %%
final_dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner  Current_Year
# 0       Dealer       Manual      0          2023
# 1       Dealer       Manual      0          2023
# 2       Dealer       Manual      0          2023
# 3       Dealer       Manual      0          2023
# 4       Dealer       Manual      0          2023

# %%
# to find age of cars according to the price
final_dataset['Age']=final_dataset['Current_Year']-final_dataset['Year']

# %%
final_dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner  Current_Year  Age
# 0       Dealer       Manual      0          2023    9
# 1       Dealer       Manual      0          2023   10
# 2       Dealer       Manual      0          2023    6
# 3       Dealer       Manual      0          2023   12
# 4       Dealer       Manual      0          2023    9

# %%
# drop column labelled as year and dosent return a copy as a inplace
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
# drop column labelled as Current_year and dosent return a copy as a inplace
final_dataset.drop(['Current_Year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type
# 0     ritz           3.35           5.59       27000    Petrol       Dealer  \
# 1      sx4           4.75           9.54       43000    Diesel       Dealer
# 2     ciaz           7.25           9.85        6900    Petrol       Dealer
# 3  wagon r           2.85           4.15        5200    Petrol       Dealer
# 4    swift           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    9
# 1       Manual      0   10
# 2       Manual      0    6
# 3       Manual      0   12
# 4       Manual      0    9

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
# removes multiple columns of the dataset as some  columns contain the same
#information because the orignal column could assume a binary value

final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age  Car_Name_Activa 3g
# 0           3.35           5.59       27000      0    9               False  \
# 1           4.75           9.54       43000      0   10               False
# 2           7.25           9.85        6900      0    6               False
# 3           2.85           4.15        5200      0   12               False
# 4           4.60           6.87       42450      0    9               False
#
#    Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# 0               False                   False                       False  \
# 1               False                   False                       False
# 2               False                   False                       False
# 3               False                   False                       False
# 4               False                   False                       False
#
#    Car_Name_Bajaj Avenger 150 street  ...  Car_Name_swift  Car_Name_sx4
# 0                              False  ...           False         False  \
# 1                              False  ...           False          True
# 2                              False  ...           False         False
# 3                              False  ...           False         False
# 4                              False  ...            True         False
#
#    Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  Car_Name_xcent
# 0           False                   False             False           False  \
# 1           False                   False             False           False
# 2           False                   False             False           False
# 3           False                   False              True           False
# 4           False                   False             False           False
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual
# 0             False              True                    False  \
# 1              True             False                    False
# 2             False              True                    False
# 3             False              True                    False
# 4              True             False                    False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
#
# [5 rows x 106 columns]

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age  Car_Name_Activa 3g
# 0             3.35           5.59       27000      0    9               False  \
# 1             4.75           9.54       43000      0   10               False
# 2             7.25           9.85        6900      0    6               False
# 3             2.85           4.15        5200      0   12               False
# 4             4.60           6.87       42450      0    9               False
# ..             ...            ...         ...    ...  ...                 ...
# 296           9.50          11.60       33988      0    7               False
# 297           4.00           5.90       60000      0    8               False
# 298           3.35          11.00       87934      0   14               False
# 299          11.50          12.50        9000      0    6               False
# 300           5.30           5.90        5464      0    7               False
#
#      Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# 0                 False                   False                       False  \
# 1                 False                   False                       False
# 2                 False                   False                       False
# 3                 False                   False                       False
# 4                 False                   False                       False
# ..                  ...                     ...                         ...
# 296               False                   False                       False
# 297               False                   False                       False
# 298               False                   False                       False
# 299               False                   False                       False
# 300               False                   False                       False
#
#      Car_Name_Bajaj Avenger 150 street  ...  Car_Name_swift  Car_Name_sx4
# 0                                False  ...           False         False  \
# 1                                False  ...           False          True
# 2                                False  ...           False         False
# 3                                False  ...           False         False
# 4                                False  ...            True         False
# ..                                 ...  ...             ...           ...
# 296                              False  ...           False         False
# 297                              False  ...           False         False
# 298                              False  ...           False         False
# 299                              False  ...           False         False
# 300                              False  ...           False         False
#
#      Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  Car_Name_xcent
# 0             False                   False             False           False  \
# 1             False                   False             False           False
# 2             False                   False             False           False
# 3             False                   False              True           False
# 4             False                   False             False           False
# ..              ...                     ...               ...             ...
# 296           False                   False             False           False
# 297           False                   False             False           False
# 298           False                   False             False           False
# 299           False                   False             False           False
# 300           False                   False             False           False
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual
# 0               False              True                    False  \
# 1                True             False                    False
# 2               False              True                    False
# 3               False              True                    False
# 4                True             False                    False
# ..                ...               ...                      ...
# 296              True             False                    False
# 297             False              True                    False
# 298             False              True                    False
# 299              True             False                    False
# 300             False              True                    False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 106 columns]

# %%
# to find the pairwise correletion of all columns in the dataframe
final_dataset.corr(method='pearson')
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner
# Selling_Price                 1.000000       0.878914    0.029187 -0.088344  \
# Present_Price                 0.878914       1.000000    0.203618  0.008058
# Driven_kms                    0.029187       0.203618    1.000000  0.089216
# Owner                        -0.088344       0.008058    0.089216  1.000000
# Age                          -0.236141       0.047192    0.524342  0.182104
# ...                                ...            ...         ...       ...
# Car_Name_xcent                0.006038      -0.005797   -0.024550  0.117621
# Fuel_Type_Diesel              0.552339       0.473390    0.172515 -0.053469
# Fuel_Type_Petrol             -0.540571      -0.465326   -0.172874  0.055687
# Selling_type_Individual      -0.550724      -0.512121   -0.101419  0.124269
# Transmission_Manual          -0.367128      -0.348776   -0.162510 -0.050316
#
#                               Age  Car_Name_Activa 3g  Car_Name_Activa 4g
# Selling_Price           -0.236141           -0.070132           -0.048484  \
# Present_Price            0.047192           -0.067286           -0.047633
# Driven_kms               0.524342            0.449361           -0.053013
# Owner                    0.182104           -0.014272           -0.010075
# Age                      1.000000            0.046121           -0.067442
# ...                           ...                 ...                 ...
# Car_Name_xcent          -0.059276           -0.008206           -0.005793
# Fuel_Type_Diesel        -0.064315           -0.040808           -0.028808
# Fuel_Type_Petrol         0.059959            0.041656            0.029406
# Selling_type_Individual  0.039896            0.110929            0.078308
# Transmission_Manual     -0.000394           -0.208915           -0.147479
#
#                          Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# Selling_Price                         -0.050987                   -0.044502  \
# Present_Price                         -0.048904                   -0.045692
# Driven_kms                            -0.002896                   -0.044536
# Owner                                 -0.010075                   -0.010075
# Age                                   -0.027442                   -0.047442
# ...                                         ...                         ...
# Car_Name_xcent                        -0.005793                   -0.005793
# Fuel_Type_Diesel                      -0.028808                   -0.028808
# Fuel_Type_Petrol                       0.029406                    0.029406
# Selling_type_Individual                0.078308                    0.078308
# Transmission_Manual                    0.022602                    0.022602
#
#                          Car_Name_Bajaj Avenger 150 street  ...
# Selling_Price                                    -0.046209  ...  \
# Present_Price                                    -0.045692  ...
# Driven_kms                                       -0.025203  ...
# Owner                                            -0.010075  ...
# Age                                              -0.047442  ...
# ...                                                    ...  ...
# Car_Name_xcent                                   -0.005793  ...
# Fuel_Type_Diesel                                 -0.028808  ...
# Fuel_Type_Petrol                                  0.029406  ...
# Selling_type_Individual                           0.078308  ...
# Transmission_Manual                               0.022602  ...
#
#                          Car_Name_swift  Car_Name_sx4  Car_Name_verna
# Selling_Price                 -0.003107     -0.042241        0.062962  \
# Present_Price                 -0.019378      0.007243        0.043519
# Driven_kms                    -0.008000      0.050668        0.032997
# Owner                         -0.022680     -0.024886       -0.038541
# Age                           -0.007748      0.212166        0.004321
# ...                                 ...           ...             ...
# Car_Name_xcent                -0.013040     -0.014309       -0.022160
# Fuel_Type_Diesel               0.065282     -0.011662        0.126733
# Fuel_Type_Petrol              -0.062353     -0.044910       -0.121563
# Selling_type_Individual       -0.041403     -0.105148       -0.162839
# Transmission_Manual            0.050880     -0.014190        0.039989
#
#                          Car_Name_vitara brezza  Car_Name_wagon r
# Selling_Price                          0.052209         -0.049143  \
# Present_Price                          0.014731         -0.042751
# Driven_kms                            -0.051867          0.011053
# Owner                                 -0.010075         -0.020251
# Age                                   -0.087442          0.095596
# ...                                         ...               ...
# Car_Name_xcent                        -0.005793         -0.011644
# Fuel_Type_Diesel                       0.115710         -0.057905
# Fuel_Type_Petrol                      -0.113355         -0.012632
# Selling_type_Individual               -0.042567         -0.085563
# Transmission_Manual                    0.022602          0.045432
#
#                          Car_Name_xcent  Fuel_Type_Diesel  Fuel_Type_Petrol
# Selling_Price                  0.006038          0.552339         -0.540571  \
# Present_Price                 -0.005797          0.473390         -0.465326
# Driven_kms                    -0.024550          0.172515         -0.172874
# Owner                          0.117621         -0.053469          0.055687
# Age                           -0.059276         -0.064315          0.059959
# ...                                 ...               ...               ...
# Car_Name_xcent                 1.000000         -0.050063          0.051103
# Fuel_Type_Diesel              -0.050063          1.000000         -0.979648
# Fuel_Type_Petrol               0.051103         -0.979648          1.000000
# Selling_type_Individual       -0.073976         -0.350467          0.358321
# Transmission_Manual            0.039279         -0.098643          0.091013
#
#                          Selling_type_Individual  Transmission_Manual
# Selling_Price                          -0.550724            -0.367128
# Present_Price                          -0.512121            -0.348776
# Driven_kms                             -0.101419            -0.162510
# Owner                                   0.124269            -0.050316
# Age                                     0.039896            -0.000394
# ...                                          ...                  ...
# Car_Name_xcent                         -0.073976             0.039279
# Fuel_Type_Diesel                       -0.350467            -0.098643
# Fuel_Type_Petrol                        0.358321             0.091013
# Selling_type_Individual                 1.000000             0.063240
# Transmission_Manual                     0.063240             1.000000
#
# [106 rows x 106 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# to display the plot

# %%
# warnigs  depending on the version of python and libraries are used so make it off
import warnings
warnings.filterwarnings('ignore')

corrmat=df.corr(method='pearson')

# %%
corrmat.index

# %%
import seaborn as sns
# get correletions of each features in dataset
corrmat=df.corr(method='pearson')
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
# plot the heat map of the correletioin of the features
g=sns.heatmap(df[top_corr_features].corr(method='pearson'),annot=True,cmap="RdYlGn")
# annot=true will write the data in each cell

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age  Car_Name_Activa 3g
# 0             3.35           5.59       27000      0    9               False  \
# 1             4.75           9.54       43000      0   10               False
# 2             7.25           9.85        6900      0    6               False
# 3             2.85           4.15        5200      0   12               False
# 4             4.60           6.87       42450      0    9               False
# ..             ...            ...         ...    ...  ...                 ...
# 296           9.50          11.60       33988      0    7               False
# 297           4.00           5.90       60000      0    8               False
# 298           3.35          11.00       87934      0   14               False
# 299          11.50          12.50        9000      0    6               False
# 300           5.30           5.90        5464      0    7               False
#
#      Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# 0                 False                   False                       False  \
# 1                 False                   False                       False
# 2                 False                   False                       False
# 3                 False                   False                       False
# 4                 False                   False                       False
# ..                  ...                     ...                         ...
# 296               False                   False                       False
# 297               False                   False                       False
# 298               False                   False                       False
# 299               False                   False                       False
# 300               False                   False                       False
#
#      Car_Name_Bajaj Avenger 150 street  ...  Car_Name_swift  Car_Name_sx4
# 0                                False  ...           False         False  \
# 1                                False  ...           False          True
# 2                                False  ...           False         False
# 3                                False  ...           False         False
# 4                                False  ...            True         False
# ..                                 ...  ...             ...           ...
# 296                              False  ...           False         False
# 297                              False  ...           False         False
# 298                              False  ...           False         False
# 299                              False  ...           False         False
# 300                              False  ...           False         False
#
#      Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  Car_Name_xcent
# 0             False                   False             False           False  \
# 1             False                   False             False           False
# 2             False                   False             False           False
# 3             False                   False              True           False
# 4             False                   False             False           False
# ..              ...                     ...               ...             ...
# 296           False                   False             False           False
# 297           False                   False             False           False
# 298           False                   False             False           False
# 299           False                   False             False           False
# 300           False                   False             False           False
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual
# 0               False              True                    False  \
# 1                True             False                    False
# 2               False              True                    False
# 3               False              True                    False
# 4                True             False                    False
# ..                ...               ...                      ...
# 296              True             False                    False
# 297             False              True                    False
# 298             False              True                    False
# 299              True             False                    False
# 300             False              True                    False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 106 columns]

# %%
final_dataset.iloc[:,0]
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
# slicing the datset and removing the selling price 
x=final_dataset.iloc[:,1:]
# storing the selling price for checking as this is the value
y=final_dataset.iloc[:,0]

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age  Car_Name_Activa 3g
# 0           3.35           5.59       27000      0    9               False  \
# 1           4.75           9.54       43000      0   10               False
# 2           7.25           9.85        6900      0    6               False
# 3           2.85           4.15        5200      0   12               False
# 4           4.60           6.87       42450      0    9               False
#
#    Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# 0               False                   False                       False  \
# 1               False                   False                       False
# 2               False                   False                       False
# 3               False                   False                       False
# 4               False                   False                       False
#
#    Car_Name_Bajaj Avenger 150 street  ...  Car_Name_swift  Car_Name_sx4
# 0                              False  ...           False         False  \
# 1                              False  ...           False          True
# 2                              False  ...           False         False
# 3                              False  ...           False         False
# 4                              False  ...            True         False
#
#    Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  Car_Name_xcent
# 0           False                   False             False           False  \
# 1           False                   False             False           False
# 2           False                   False             False           False
# 3           False                   False              True           False
# 4           False                   False             False           False
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual
# 0             False              True                    False  \
# 1              True             False                    False
# 2             False              True                    False
# 3             False              True                    False
# 4              True             False                    False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
#
# [5 rows x 106 columns]

# %%
x.head()
# Out:
#    Present_Price  Driven_kms  Owner  Age  Car_Name_Activa 3g
# 0           5.59       27000      0    9               False  \
# 1           9.54       43000      0   10               False
# 2           9.85        6900      0    6               False
# 3           4.15        5200      0   12               False
# 4           6.87       42450      0    9               False
#
#    Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150
# 0               False                   False                       False  \
# 1               False                   False                       False
# 2               False                   False                       False
# 3               False                   False                       False
# 4               False                   False                       False
#
#    Car_Name_Bajaj Avenger 150 street  Car_Name_Bajaj Avenger 220  ...
# 0                              False                       False  ...  \
# 1                              False                       False  ...
# 2                              False                       False  ...
# 3                              False                       False  ...
# 4                              False                       False  ...
#
#    Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza
# 0           False         False           False                   False  \
# 1           False          True           False                   False
# 2           False         False           False                   False
# 3           False         False           False                   False
# 4            True         False           False                   False
#
#    Car_Name_wagon r  Car_Name_xcent  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0             False           False             False              True  \
# 1             False           False              True             False
# 2             False           False             False              True
# 3              True           False             False              True
# 4             False           False              True             False
#
#    Selling_type_Individual  Transmission_Manual
# 0                    False                 True
# 1                    False                 True
# 2                    False                 True
# 3                    False                 True
# 4                    False                 True
#
# [5 rows x 105 columns]

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
# in ensemble prediction of several base estimators are built in with a given learning algorithm
# we used ExtraTreesRegression
model=ExtraTreesRegressor()
# this class implements a meta estimator that fits a number of randomized decision trees
# on various sub-samples of the dataset and uses averaging to improve the
# predictive accuracy and control over-fitting.
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# shows the features importances that contribute to the selling price feature
# Out:
# [2.85858385e-01 3.04491552e-02 7.23425580e-05 7.15593485e-02
#  1.59687405e-07 4.60192905e-07 2.96911842e-06 1.29493271e-06
#  1.95527170e-07 9.21201812e-06 1.20166887e-06 1.84763173e-08
#  8.67347535e-08 2.81055884e-07 5.68364151e-06 2.25772514e-06
#  3.04896164e-07 5.07580303e-06 2.12593602e-06 3.67096454e-06
#  2.34542860e-06 1.39987940e-06 1.77154681e-06 4.80484062e-06
#  1.77311390e-07 1.08316009e-06 3.69295705e-07 5.69727273e-08
#  4.45993192e-08 9.16012480e-07 1.02439434e-06 1.20425801e-07
#  7.91971229e-08 8.66957606e-07 1.94493029e-08 2.81302374e-06
#  6.26203813e-07 1.10949610e-06 1.74300111e-06 9.64882098e-07
#  2.30557323e-05 9.91925113e-09 9.52024839e-06 1.61590373e-06
#  1.64321396e-06 1.37283511e-05 1.90179312e-05 5.47341987e-06
#  5.41247846e-06 1.17858250e-04 1.80708706e-05 4.39509728e-05
#  3.62978256e-05 1.38187029e-07 3.81374598e-06 1.41606591e-06
#  3.51181544e-07 8.46654812e-08 5.60083748e-08 1.50382261e-05
#  5.32473958e-07 4.58549447e-06 8.20541938e-07 1.25824679e-06
#  9.68165885e-07 4.04085652e-05 2.05192405e-04 2.06316734e-04
#  1.11708644e-05 3.24585044e-04 8.69176228e-05 1.93006614e-03
#  6.87233571e-03 2.81756803e-04 8.72304650e-03 3.47115431e-03
#  1.02175385e-04 8.46820746e-04 4.89830718e-04 2.99102212e-04
#  2.50564216e-04 5.11280542e-05 1.39288244e-04 5.90033460e-05
#  1.31805595e-02 5.70569788e-04 8.60985164e-05 2.93096830e-04
#  4.08688839e-05 1.52669536e-02 3.43499501e-04 3.42700896e-02
#  2.23827333e-04 1.69675579e-04 1.13727588e-04 2.79944625e-03
#  2.64728012e-04 1.94034609e-03 1.57751582e-04 1.19050110e-04
#  4.94431866e-05 2.30633133e-01 5.68496310e-03 1.41230433e-01
#  1.39849591e-01]

# %%
#plot graph of feaature importance for the better visualization
feat_importances=pd.Series(model.feature_importances_,index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.title('feature importances')
plt.show()

# %%
from sklearn.model_selection import train_test_split #class to divide the data into train and visualize
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
#we divide the data into 2 parts 80% train and 20% test data and randon state is used to guarantee that 
#same sequence of Brandon numbers are generated each cine you run the code. 
#And unless there is some other randomness present in the process, 
#the results produced will be same as always.

# %%
x_train.shape
# Out:
# (240, 105)

# %%
from sklearn.ensemble import RandomForestRegressor
regresor=RandomForestRegressor()

# %%
import numpy as np
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
#n_estimators is a parameter of the random forest regressor which is used to control no of trees
# so we use 100 200......1200 trees for the model
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search Cv
#number of features to consider at every split 
max_features =['auto','sqrt']
# we first consider all the features and
#then sqare rout number of features to train the model

#Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num=6)] 
#we create trees with 5 10 15 for each model...and train it

#Minimum number of samples required to split a node

min_samples_split=[2, 5, 10, 15, 100] 

#we split as 2 nodes forst then 5 then 10 Like that till 100 from the list

#Minimum number of samples required at each leaf node 
min_samples_leaf =[1, 2, 5, 10]

# %%
max_depth
# Out:
# [5, 10, 15, 20, 25, 30]

# %%
from sklearn.model_selection import RandomizedSearchCV
#randomized search on hyper parameters
#used to select the best parameter for the model

# %%
random_grid={'n_estimators':n_estimators,
           'max_features':max_features,
           'max_depth' :max_depth,
           'min_samples_split':min_samples_split,
            'min_samples_leaf':min_samples_leaf}    
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf=RandomForestRegressor()
# random search of parameter,using 3 fold cross validation
#search across 100 different combinations
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error')

# %%
rf_random.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    scoring='neg_mean_squared_error')

# %%
predictions=rf_random.predict(x_test)

# %%
predictions1=rf_random.predict(x_train)

# %%
sns.displot(y_test-predictions)

# %%
sns.displot(y_train-predictions1)

# %%
plt.scatter(y_test,predictions)

# %%
plt.scatter(y_train,predictions1)

# %%
import pickle
# open a file where you ant to store the data
file=open('random_forest_regression_model.pkl','wb')

# dump information to that file
pickle.dump(rf_random,file)
# we use a pickle file to store tha data in a byte stream

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,predictions)
rmse=np.sqrt(mse)
print("RMSE:{:.2f}".format(rmse))
# Out:
# RMSE:1.20

# %%
from sklearn.metrics import r2_score
r=r2_score(y_test,predictions)
print("r2 score:{}".format(r))
# Out:
# r2 score:0.9432362800493906

# %%
df_check=pd.DataFrame({'Actual':y_test,'predicted':predictions})
df_check=df_check.head(25)
# round(df_check,2)
df_check.plot(kind="bar",figsize=(10,5))
plt.grid(which='major',linestyle='-',linewidth='0.5',color='green')
plt.title("performance of random forest")
plt.ylabel('price')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse_predict=round(mean_squared_error(y_test,predictions),4)
mae_predict=round(mean_absolute_error(y_test,predictions),4)
print("MSE is:"+str(mse_predict))
print("MAE is:"+str(mae_predict))
# Out:
# MSE is:1.4348
# MAE is:0.6549

# %%
cutoff=1.8 # decide on a cutoff limit
y_pred_classes=np.zeros_like(predictions)
y_test_classes=np.zeros_like(predictions) # initialize matrix full with zeros
y_pred_classes[abs(y_test-predictions)>cutoff]=1

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test_classes,y_pred_classes)

# %%
df_cm=cm
sns.heatmap(df_cm,annot=True,cmap="Blues",annot_kws={"size":20})
plt.title("confusion matrix")
# Out:
# Text(0.5, 1.0, 'confusion matrix')

# %%
from sklearn.metrics import classification_report
matrix=classification_report(y_test_classes,y_pred_classes)
print(matrix)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        61
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.95        61
#    macro avg       0.50      0.48      0.49        61
# weighted avg       1.00      0.95      0.97        61

# %%
from sklearn.metrics import accuracy_score
s=accuracy_score(y_test_classes,y_pred_classes)
print("accuracy of the model:{}".format(s))
# Out:
# accuracy of the model:0.9508196721311475
